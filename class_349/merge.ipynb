# %%
import pandas as pd

# %%
army = pd.read_excel('added/uni/Преподаватель вуза - военное дело и безопасность.xlsx')

# %%
design = pd.read_excel('added/uni/Преподаватель вуза -архитектура и дизайн.xlsx')

# %%
pedagogic = pd.read_excel('added/uni/Преподаватель вуза - педагогика.xlsx')

# %%
indusrty = pd.read_excel('added/uni/Преподаватель вуза -промышленность и производство.xlsx')

# %%
medical = pd.read_excel('added/uni/Преподаватель вуза - медицина.xlsx')

# %%
agriculture = pd.read_excel('added/uni/Преподаватель вуза - сельское хозяйство1.xlsx')

# %%
turism = pd.read_excel('added/uni/Преподаватель вуза - туризм.xlsx')

# %%
ict = pd.read_excel('added/uni/Преподаватель вуза -информатика и ИКТ.xlsx')

# %%
science = pd.read_excel('added/uni/Преподаватель вуза -естественные науки.xlsx')

# %%
economy = pd.read_excel('added/uni/Преподаватель вуза - экономика и финансы.xlsx')

# %%
political = pd.read_excel('added/uni/Преподаватель вуза - общественные науки.xlsx')

# %%
legal = pd.read_excel('added/uni/Преподаватель вуза - юридические дисциплины.xlsx')

# %%
humanity = pd.read_excel('added/uni/Преподаватель вуза - гуманитарные науки(2).xlsx')

# %%
lang = pd.read_excel('added/uni/Преподаватель вуза - языки.xlsx')

# %%
art = pd.read_excel('added/uni/Преподаватель вуза - искусство.xlsx')

# %%
df.to_excel('university.xlsx')

# %%
df = pd.concat([army, design, pedagogic, indusrty, medical, agriculture, turism,ict,  science,economy, political, legal, humanity, lang,art], ignore_index = False)

# %%
df_college = pd.concat([science_,medical_cl, arch,turism_cl,econony_cl,industry_cl,ict_college,lang_college,legal_college,humanity], ignore_index = False)

# %%
pedagogic = pedagogic.drop('class', axis=1)

# %%
art['class'] = 32

# %%
len(df['class'].value_counts())
# Out:
# 15

# %%
lang = lang.head(210)

# %%
c_1 = pd.read_excel('added/college/fix/Преподаватель_колледжа_юридические_дисциплины1.xlsx')
c_2 = pd.read_excel('added/college/fix/Преподаватель_колледжа_экономика_и_финансы1.xlsx')
c_3 = pd.read_excel('added/college/fix/Преподаватель_колледжа_промышленность_и_производство1.xlsx')
c_4 = pd.read_excel('added/college/fix/Преподаватель_колледжа_общественные_науки1.xlsx')
c_5 = pd.read_excel('added/college/fix/Преподаватель_колледжа_медицина1.xlsx')
c_6 = pd.read_excel('added/college/fix/Преподаватель_колледжа_информатика_и_ИКТ1.xlsx')
c_7 = pd.read_excel('added/college/fix/Преподаватель_колледжа_гуманитарные_науки.xlsx')
c_8 = pd.read_excel('added/college/fix/Преподаватель_колледжа_архитектура_и_дизайн1.xlsx')
c_9 = pd.read_excel('added/college/fix/Преподаватель колледжа - языки(1).xlsx')
c_10 = pd.read_excel('added/college/fix/Преподаватель_колледжа_туризм1.xlsx')

# %%
df_college = pd.concat([c_1, c_2, c_3, c_4, c_5, c_6, c_7, c_8, c_9, c_10], ignore_index=False)

# %%
df_univer = df

# %%
df = pd.concat([df_college, df_univer], ignore_index=False)

# %%
c_11 = pd.read_excel('fix_for_extract/75_full.xlsx')
c_12 = pd.read_excel('fix_for_extract/67_full.xlsx')
c_13 = pd.read_excel('fix_for_extract/49_full.xlsx')
c_14 = pd.read_excel('fix_for_extract/4_full.xlsx')
c_15 = pd.read_excel('fix_for_extract/36_full.xlsx')
c_16 = pd.read_excel('fix_for_extract/268_full.xlsx')
c_17 = pd.read_excel('fix_for_extract/253_full.xlsx')
c_18 = pd.read_excel('fix_for_extract/252_full.xlsx')
c_19 = pd.read_excel('fix_for_extract/250_full.xlsx')
c_20 = pd.read_excel('fix_for_extract/248_full.xlsx')
c_21 = pd.read_excel('fix_for_extract/246_full.xlsx')
c_22 = pd.read_excel('fix_for_extract/239_full.xlsx')
c_23 = pd.read_excel('fix_for_extract/237_full.xlsx')
c_24 = pd.read_excel('fix_for_extract/236_full.xlsx')
c_25 = pd.read_excel('fix_for_extract/215_full.xlsx')
c_26 = pd.read_excel('fix_for_extract/212_full.xlsx')
c_27 = pd.read_excel('fix_for_extract/194_full.xlsx')
c_28 = pd.read_excel('fix_for_extract/187_full.xlsx')
c_29 = pd.read_excel('fix_for_extract/138_full.xlsx')
c_30 = pd.read_excel('fix_for_extract/136_full.xlsx')
c_31 = pd.read_excel('fix_for_extract/122_full.xlsx')
c_32 = pd.read_excel('fix_for_extract/120_full.xlsx')
c_33 = pd.read_excel('fix_for_extract/115_full.xlsx')
c_34 = pd.read_excel('fix_for_extract/109_full.xlsx')
c_35 = pd.read_excel('fix_for_extract/104_full.xlsx')

# %%
c_11 = c_11[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_12 = c_12[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_13 = c_13[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_14 = c_14[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_15 = c_15[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_16 = c_16[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_17 = c_17[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_18 = c_18[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_19 = c_19[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_20 = c_20[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_21 = c_21[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_22 = c_22[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_23 = c_23[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_24 = c_24[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_25 = c_25[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_26 = c_26[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_27 = c_27[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_28 = c_28[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_29 = c_29[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_30 = c_30[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_31 = c_31[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_32 = c_32[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_33 = c_33[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_34 = c_34[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_35 = c_35[['Unnamed: 0', 'name', 'response', 'class', 'id']]

# %%
c_11.rename(columns={'response': 'description'}, inplace=True)
c_12.rename(columns={'response': 'description'}, inplace=True)
c_13.rename(columns={'response': 'description'}, inplace=True)
c_14.rename(columns={'response': 'description'}, inplace=True)
c_15.rename(columns={'response': 'description'}, inplace=True)
c_16.rename(columns={'response': 'description'}, inplace=True)
c_17.rename(columns={'response': 'description'}, inplace=True)
c_18.rename(columns={'response': 'description'}, inplace=True)
c_19.rename(columns={'response': 'description'}, inplace=True)
c_20.rename(columns={'response': 'description'}, inplace=True)
c_21.rename(columns={'response': 'description'}, inplace=True)
c_22.rename(columns={'response': 'description'}, inplace=True)
c_23.rename(columns={'response': 'description'}, inplace=True)
c_24.rename(columns={'response': 'description'}, inplace=True)
c_25.rename(columns={'response': 'description'}, inplace=True)
c_26.rename(columns={'response': 'description'}, inplace=True)
c_27.rename(columns={'response': 'description'}, inplace=True)
c_28.rename(columns={'response': 'description'}, inplace=True)
c_29.rename(columns={'response': 'description'}, inplace=True)
c_30.rename(columns={'response': 'description'}, inplace=True)
c_31.rename(columns={'response': 'description'}, inplace=True)
c_32.rename(columns={'response': 'description'}, inplace=True)
c_33.rename(columns={'response': 'description'}, inplace=True)
c_34.rename(columns={'response': 'description'}, inplace=True)
c_35.rename(columns={'response': 'description'}, inplace=True)

# %%
c_11['class'] = 75
c_12['class'] = 67
c_13['class'] = 49
c_14['class'] = 4
c_15['class'] = 36
c_16['class'] = 268
c_17['class'] = 253
c_18['class'] = 252
c_19['class'] = 250
c_20['class'] = 248
c_21['class'] = 246
c_22['class'] = 239
c_23['class'] = 237
c_24['class'] = 236
c_25['class'] = 215
c_26['class'] = 212
c_27['class'] = 194
c_28['class'] = 187
c_29['class'] = 138
c_30['class'] = 136
c_31['class'] = 122
c_32['class'] = 120
c_33['class'] = 115
c_34['class'] = 109
c_35['class'] = 104

# %%
df_1 = pd.concat([c_11, c_12, c_13, c_14, c_15, c_16, c_17, c_18, c_19, c_20, c_21, c_22, c_23, c_24, c_25, c_26, c_27, c_28, c_29, c_30, c_31, c_32, c_33, c_34, c_35], ignore_index=False)

# %%
df_merged = pd.concat([df, df_1], ignore_index=False)

# %%
df_1.rename(columns={'response': 'description'}, inplace=True)

# %%
df_0 = df

# %%
df = pd.concat([df_0, df_1], ignore_index=False)

# %%
len(df['class'].value_counts())
# Out:
# 50

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(25, 6))
df['class'].value_counts().plot(kind='bar')
plt.title("Распределение значений в колонке 'class'")
plt.xlabel("Класс")
plt.ylabel("Количество")
plt.xticks(rotation=0)
plt.show()

# %%
c_36 = pd.read_excel('fix_for_extract/281_full.xlsx')
c_37 = pd.read_excel('fix_for_extract/298_full.xlsx')
c_38 = pd.read_excel('fix_for_extract/283_full.xlsx')
c_39 = pd.read_excel('fix_for_extract/271_full.xlsx')
c_40 = pd.read_excel('fix_for_extract/323_full (1).xlsx')
c_41 = pd.read_excel('fix_for_extract/317_full.xlsx')

# %%
c_36 = c_36[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_37 = c_37[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_38 = c_38[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_39 = c_39[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_40 = c_40[['Unnamed: 0', 'name', 'response', 'class', 'id']]
c_41 = c_41[['Unnamed: 0', 'name', 'response', 'class', 'id']]

# %%
c_36.rename(columns={'response':'description'}, inplace=True)
c_37.rename(columns={'response':'description'}, inplace=True)
c_38.rename(columns={'response':'description'}, inplace=True)
c_39.rename(columns={'response':'description'}, inplace=True) 
c_40.rename(columns={'response':'description'}, inplace=True)
c_41.rename(columns={'response':'description'}, inplace=True)

# %%
c_36['class'] = 281
c_37['class'] = 298
c_38['class'] = 283
c_39['class'] = 271
c_40['class'] = 323
c_41['class'] = 317
# Out:
# /tmp/ipykernel_12750/431798863.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_36['class'] = 281
# /tmp/ipykernel_12750/431798863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_37['class'] = 298
# /tmp/ipykernel_12750/431798863.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2 = pd.concat([c_36,c_37,c_38,c_39,c_40,c_41], ignore_index=False)

# %%
df_2['class'].value_counts()
# Out:
# class
# 281    201
# 298    201
# 271    201
# 283    200
# 323    200
# 317    200
# Name: count, dtype: int64

# %%
df = pd.concat([df_0, df_1, df_2], ignore_index=False)

# %%
df_2.rename(columns={'response':'description'}, inplace=True)

# %%
df
# Out:
#      Unnamed: 0                                               name  \
# 0         106.0  Эксперт 1 категории Отдела развития человеческ...
# 1         184.0  Преподаватель специальных дисциплин (программист)
# 2         215.0                         Преподаватель правоведения
# 3         417.0  Преподаватель юридических дисциплин (на госуда...
# 4         687.0  Преподаватель юридических дисциплин на русском...
# ..          ...                                                ...
# 195         NaN                                                NaN
# 196         NaN                                                NaN
# 197         NaN                                                NaN
# 198         NaN                                                NaN
# 199         NaN                                                NaN
#
#                                            description  class  id
# 0    профиль образования высшее гуманитарное юридич...     76 NaN
# ...

# %%
plt.figure(figsize=(25, 6))
df['class'].value_counts().plot(kind='bar')
plt.title("Распределение значений в колонке 'class'")
plt.xlabel("Класс")
plt.ylabel("Количество")
plt.xticks(rotation=0)
plt.show()

# %%
dataset = pd.read_csv('200_profession/dataset.csv')

# %%
index = dataset['class'].value_counts().sort_index()

# %%
index_cnt = index[index<150]

# %%
len(index_cnt)
# Out:
# 22

# %%
index_cnt.index
# Out:
# Index([ 41,  42,  49,  67, 104, 113, 122, 136, 187, 194, 212, 250, 263, 268,
#        271, 274, 281, 282, 283, 285, 327, 402],
#       dtype='int64', name='class')

# %%
dataset = dataset[~dataset['class'].isin(index_cnt.index)]

# %%
dataset['class'].value_counts()
# Out:
# class
# 1      200
# 3      200
# 14     200
# 16     200
# 13     200
#       ...
# 8      155
# 215    152
# 75     151
# 120    151
# 236    150
# Name: count, Length: 178, dtype: int64

# %%
dataset = dataset[['Unnamed: 0', 'name', 'description', 'class', 'id']]

# %%
df_3 = df

# %%
df = pd.concat([df_0, df_1, df_2, dataset], ignore_index=False)

# %%
len(df['class'].value_counts())
# Out:
# 216

# %%
df['class'].value_counts()
# Out:
# class
# 248    388
# 253    388
# 239    387
# 317    386
# 237    382
# 138    382
# 252    377
# 246    375
# 323    373
# 4      371
# 115    370
# 36     368
# 109    358
# 298    356
# 215    352
# 75     352
# 120    352
# 236    350
# 69     229
# 70     215
# 47     215
# 40     211
# 42     210
# 62     206
# 59     206
# 52     206
# 73     205
# 56     205
# 71     204
# 212    203
# 49     202
# 187    202
# 76     202
# 136    202
# 271    201
# 194    201
# 281    201
# 104    201
# 122    201
# 268    201
# 1      200
# 3      200
# 14     200
# 13     200
# 16     200
# 27     200
# 26     200
# 23     200
# 81     200
# 74     200
# 39     200
# 72     200
# 250    200
# 32     200
# 67     200
# 283    200
# 82     200
# 184    200
# 242    200
# 299    200
# 209    200
# 226    200
# 204    200
# 189    200
# 127    200
# 95     200
# 131    200
# 130    200
# 101    200
# 89     200
# 94     200
# 43     199
# 132    199
# 124    199
# 29     199
# 55     199
# ...

# %%
college_art = pd.read_excel('added/college/art.xlsx')

# %%
nature.rename(columns={'profession_id':'class'}, inplace=True)

# %%
ph = pd.read_excel('added/college/физкуль.xlsx')

# %%
ped = pd.read_excel('added/college/пед.xlsx')

# %%
sel = pd.read_excel('added/college/сель.xlsx')

# %%
nature = pd.read_excel('added/college/nature.xlsx')

# %%
df_3 = pd.concat([college_art, nature, ph, ped, sel], ignore_index=False)

# %%
pd.reset_option('display.max_rows')

# %%
df_3['class'].value_counts()
# Out:
# class
# 65    200
# 38    200
# 66    198
# 50    195
# 53    194
# Name: count, dtype: int64

# %%
df = pd.concat([df_0, df_1, df_2, df_3, dataset], ignore_index=True)

# %%
df_cnt = df['class'].value_counts().sort_index()

# %%
df_cnt.to_excel('cnt.xlsx')

# %%
df_0['class'].value_counts().sort_index()
# Out:
# class
# 32    200
# 37    199
# 39    200
# 40    211
# 42    210
# 43    199
# 44    198
# 47    215
# 48    199
# 51    199
# 52    206
# 55    199
# 56    205
# 57    199
# 59    206
# 61    198
# 62    206
# 64    197
# 69    229
# 70    215
# 71    204
# 72    200
# 73    205
# 74    200
# 76    202
# Name: count, dtype: int64

# %%
df_1['class'].value_counts().sort_index()
# Out:
# class
# 4      203
# 36     199
# 49     202
# 67     200
# 75     201
# 104    201
# 109    199
# 115    204
# 120    201
# 122    201
# 136    202
# 138    201
# 187    202
# 194    201
# 212    203
# 215    200
# 236    200
# 237    201
# 239    201
# 246    201
# 248    200
# 250    200
# 252    200
# 253    202
# 268    201
# Name: count, dtype: int64

# %%
df_2['class'].value_counts().sort_index()
# Out:
# class
# 271    201
# 281    201
# 283    200
# 298    201
# 317    200
# 323    200
# Name: count, dtype: int64

# %%
df_3['class'].value_counts().sort_index()
# Out:
# class
# 38    200
# 50    195
# 53    194
# 65    200
# 66    198
# Name: count, dtype: int64

# %%
df_4['class'].value_counts().sort_index()
# Out:
# class
# 113    203
# 263    200
# 274    210
# 282    199
# 327    200
# 338    207
# 346    212
# 347    199
# 361    199
# 363    201
# 370    201
# 373    199
# 385    200
# Name: count, dtype: int64

# %%
df_5['class'].value_counts().sort_index()
# Out:
# class
# 332    250
# 333    239
# 335    250
# 336    250
# 337    250
# 340    250
# 341    250
# 342    250
# 344    250
# 348    250
# 350    250
# 351    250
# 352    250
# 353    250
# 354    250
# 355    250
# 356    250
# 357    250
# 358    250
# 360    250
# 362    250
# 364    250
# 365    250
# 366    250
# 367    250
# 368    250
# 372    204
# 374    250
# 375    250
# 377    242
# 378    250
# 379    250
# 381    250
# 383    250
# 386    250
# 387    250
# 390    209
# 391    250
# 392    250
# 394    250
# 400    250
# Name: count, dtype: int64

# %%
df_6['class'].value_counts().sort_index()
# Out:
# class
# 137    200
# 211    198
# 227    201
# 255    199
# 256    200
# 258    198
# 329    203
# Name: count, dtype: int64

# %%
df_7['class'].value_counts().sort_index()
# Out:
# class
# 225    197
# 228    199
# 284    205
# 286    210
# 345    199
# 349    204
# 369    199
# 371    199
# 376    203
# 380    213
# 382    199
# Name: count, dtype: int64

# %%
df_all = pd.concat([df_0, df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8])

# %%
df_all
# Out:
#       Unnamed: 0                                               name  \
# 0          106.0  Эксперт 1 категории Отдела развития человеческ...
# 1          184.0  Преподаватель специальных дисциплин (программист)
# 2          215.0                         Преподаватель правоведения
# 3          417.0  Преподаватель юридических дисциплин (на госуда...
# 4          687.0  Преподаватель юридических дисциплин на русском...
# ...          ...                                                ...
# 1007         NaN  Техник по обслуживанию систем автоматического ...
# 1008         NaN  Техник по обслуживанию систем мониторинга сост...
# 1009         NaN  Техник по обслуживанию систем контроля доступа...
# 1010         NaN  Техник по обслуживанию систем автоматического ...
# 1011         NaN  Техник по обслуживанию систем мониторинга сост...
#
#                                             description  class  id  \
# 0     профиль образования высшее гуманитарное юридич...     76 NaN
# ...

# %%
pd.set_option("display.max_rows", 999)

# %%
len(df_all['class'].value_counts().sort_index())
# Out:
# 138

# %%
index = df_all['class'].value_counts().sort_index()

# %%
index = index.index

# %%
index
# Out:
# Index([  4,  32,  36,  37,  38,  39,  40,  42,  43,  44,
#        ...
#        384, 385, 386, 387, 389, 390, 391, 392, 394, 400],
#       dtype='int64', name='class', length=138)

# %%
df_fil = dataset[~dataset['class'].isin(index)]

# %%
df_merge = pd.concat([df_all, df_fil])

# %%
df_merge['class'].value_counts().sort_index()

# %%
df_merge
# Out:
#      Unnamed: 0                                               name  \
# 0         106.0  Эксперт 1 категории Отдела развития человеческ...
# 1         184.0  Преподаватель специальных дисциплин (программист)
# 2         215.0                         Преподаватель правоведения
# 3         417.0  Преподаватель юридических дисциплин (на госуда...
# 4         687.0  Преподаватель юридических дисциплин на русском...
# ..          ...                                                ...
# 268      5516.0  Специалист-электронщик по ремонту компьютерной...
# 269      5517.0          Заведующий отдела компьютерных технологий
# 270      5518.0  Технический директор (Центр Информационных и К...
# 271      5519.0  IT (техник) специалист по сборке, ремонту комп...
# 272      5520.0  IT (техник) специалист по сборке, ремонту комп...
#
#                                            description  class        id  \
# 0    профиль образования высшее гуманитарное юридич...     76       NaN
# ...

# %%
df_25_class = pd.read_excel('df/25_class.xlsx')

# %%
df_merge['class'].value_counts().sort_index()
# Out:
# class
# 1      200
# 2      198
# 3      200
# 4      203
# 5      198
# 7      187
# 8      155
# 9      184
# 11     190
# 12     198
# 13     200
# 14     200
# 15     195
# 16     200
# 17     199
# 18     190
# 19     188
# 20     195
# 21     188
# 22     185
# 23     200
# 24     194
# 26     200
# 27     200
# 28     181
# 29     199
# 30     196
# 31     199
# 32     200
# 34     176
# 35     192
# 36     199
# 37     199
# 38     200
# 39     200
# 40     211
# 42     210
# 43     199
# 44     198
# 47     215
# 48     199
# 49     202
# 50     195
# 51     199
# 52     206
# 53     194
# 55     199
# 56     205
# 57     199
# 59     206
# 61     198
# 62     206
# 64     197
# 65     200
# 66     198
# 67     200
# 69     229
# 70     215
# 71     204
# 72     200
# 73     205
# 74     200
# 75     201
# 76     202
# 78     195
# 81     200
# 82     200
# 83     199
# 84     192
# 85     199
# 86     191
# 87     196
# 88     192
# 89     200
# 90     198
# 91     198
# ...

# %%
df_9 =pd.read_excel('fix_for_extract/йцуфывйцуфыв.xlsx')

# %%
df_9.rename(columns={'profession_id':'class'}, inplace=True)

# %%
df_9
# Out:
#       Unnamed: 0  id                             name  \
# 0            NaN NaN  Научный сотрудник (образование)
# 1            NaN NaN  Научный сотрудник (образование)
# 2            NaN NaN  Научный сотрудник (образование)
# 3            NaN NaN  Научный сотрудник (образование)
# 4            NaN NaN  Научный сотрудник (образование)
# ...          ...  ..                              ...
# 5672         NaN NaN               Штурман (на флоте)
# 5673         NaN NaN               Штурман (на флоте)
# 5674         NaN NaN               Штурман (на флоте)
# 5675         NaN NaN               Штурман (на флоте)
# 5676         NaN NaN               Штурман (на флоте)
#
#                                             description  class
# 0     Проведение исследований в области образования,...    275
# 1     Разработка методик и программ, анализ данных, ...    275
# 2     Проведение экспериментов, работа с аналитическ...    275
# ...

# %%
df_merge_2 = pd.concat([df_merge, df_9])

# %%
len(df_merge_2['class'].value_counts().sort_index())
# Out:
# 324

# %%
df_merge_2['class'].value_counts().sort_index()
# Out:
# class
# 1      200
# 2      198
# 3      200
# 4      203
# 5      198
# 7      187
# 8      155
# 9      184
# 11     190
# 12     198
# 13     200
# 14     200
# 15     195
# 16     200
# 17     199
# 18     190
# 19     188
# 20     195
# 21     188
# 22     185
# 23     200
# 24     194
# 26     200
# 27     200
# 28     181
# 29     199
# 30     196
# 31     199
# 32     200
# 34     176
# 35     192
# 36     199
# 37     199
# 38     200
# 39     200
# 40     211
# 42     210
# 43     199
# 44     198
# 47     215
# 48     199
# 49     202
# 50     195
# 51     199
# 52     206
# 53     194
# 55     199
# 56     205
# 57     199
# 59     206
# 61     198
# 62     206
# 64     197
# 65     200
# 66     198
# 67     200
# 69     229
# 70     215
# 71     204
# 72     200
# 73     205
# 74     200
# 75     201
# 76     202
# 78     195
# 81     200
# 82     200
# 83     199
# 84     192
# 85     199
# 86     191
# 87     196
# 88     192
# 89     200
# 90     198
# 91     198
# ...

# %%
result_df = df_merge_2.groupby('class', group_keys=False).apply(lambda x: x.sample(n=200) if len(x) > 200 else x)
# Out:
# /tmp/ipykernel_12750/1827588614.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df_merge_2.groupby('class', group_keys=False).apply(lambda x: x.sample(n=200) if len(x) > 200 else x)

# %%
result_df['class'].value_counts().sort_index()
# Out:
# class
# 1      200
# 2      198
# 3      200
# 4      200
# 5      198
# 7      187
# 8      155
# 9      184
# 11     190
# 12     198
# 13     200
# 14     200
# 15     195
# 16     200
# 17     199
# 18     190
# 19     188
# 20     195
# 21     188
# 22     185
# 23     200
# 24     194
# 26     200
# 27     200
# 28     181
# 29     199
# 30     196
# 31     199
# 32     200
# 34     176
# 35     192
# 36     199
# 37     199
# 38     200
# 39     200
# 40     200
# 42     200
# 43     199
# 44     198
# 47     200
# 48     199
# 49     200
# 50     195
# 51     199
# 52     200
# 53     194
# 55     199
# 56     200
# 57     199
# 59     200
# 61     198
# 62     200
# 64     197
# 65     200
# 66     198
# 67     200
# 69     200
# 70     200
# 71     200
# 72     200
# 73     200
# 74     200
# 75     200
# 76     200
# 78     195
# 81     200
# 82     200
# 83     199
# 84     192
# 85     199
# 86     191
# 87     196
# 88     192
# 89     200
# 90     198
# 91     198
# ...

# %%
result_df.to_csv('res.csv')
